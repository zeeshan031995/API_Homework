# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\zeesh\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\zeesh\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
temp_units = "imperial"
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data = "Output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

# %%
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)


len(cities)
# Out:
# 643

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []


count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
        
print("----------\nData Retrieval Complete\n--------------------")
# Out:
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | marsabit
# Processing Record 3 of Set 1 | thinadhoo
# Processing Record 4 of Set 1 | tasiilaq
# City not found. Skipping...
# Processing Record 5 of Set 1 | san patricio
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | kichera
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | tigzirt
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | hollins
# Processing Record 17 of Set 1 | severo-kurilsk
# Processing Record 18 of Set 1 | poum
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | nurota
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | brazzaville
# Processing Record 23 of Set 1 | urmary
# Processing Record 24 of Set 1 | turan
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | peleduy
# Processing Record 27 of Set 1 | codrington
# Processing Record 28 of Set 1 | constitucion
# Processing Record 29 of Set 1 | nikolskoye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 1 | yulara
# Processing Record 31 of Set 1 | linhai
# Processing Record 32 of Set 1 | padang
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | longyearbyen
# City not found. Skipping...
# Processing Record 35 of Set 1 | kommunisticheskiy
# City not found. Skipping...
# Processing Record 36 of Set 1 | bambanglipuro
# Processing Record 37 of Set 1 | synya
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | pacific grove
# City not found. Skipping...
# Processing Record 40 of Set 1 | langres
# Processing Record 41 of Set 1 | mehamn
# Processing Record 42 of Set 1 | kruisfontein
# Processing Record 43 of Set 1 | awjilah
# Processing Record 44 of Set 1 | eatonton
# Processing Record 45 of Set 1 | iqaluit
# City not found. Skipping...
# Processing Record 46 of Set 1 | mys shmidta
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | tuy hoa
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | mahina
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | sinnamary
# City not found. Skipping...
# Processing Record 6 of Set 2 | port hedland
# City not found. Skipping...
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | marawi
# City not found. Skipping...
# Processing Record 9 of Set 2 | axim
# Processing Record 10 of Set 2 | bairiki
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | marzuq
# Processing Record 13 of Set 2 | aksarka
# Processing Record 14 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | savannah bight
# Processing Record 17 of Set 2 | gejiu
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | vestmannaeyjar
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | aksu
# Processing Record 22 of Set 2 | rikitea
# Processing Record 23 of Set 2 | ishim
# Processing Record 24 of Set 2 | falmouth
# Processing Record 25 of Set 2 | kaitangata
# Processing Record 26 of Set 2 | boddam
# Processing Record 27 of Set 2 | airai
# City not found. Skipping...
# Processing Record 28 of Set 2 | pisco
# Processing Record 29 of Set 2 | port blair
# Processing Record 30 of Set 2 | bilma
# Processing Record 31 of Set 2 | nikki
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | lamu
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | ertil
# Processing Record 37 of Set 2 | pierre
# Processing Record 38 of Set 2 | santa cruz
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | alton
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | plettenberg bay
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | oksfjord
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | maymyo
# Processing Record 48 of Set 2 | deputatskiy
# Processing Record 49 of Set 2 | bethel
# City not found. Skipping...
# Processing Record 1 of Set 3 | cherskiy
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | frontignan
# Processing Record 4 of Set 3 | baykit
# Processing Record 5 of Set 3 | grand river south east
# Processing Record 6 of Set 3 | kapaa
# Processing Record 7 of Set 3 | banda aceh
# Processing Record 8 of Set 3 | moron
# City not found. Skipping...
# Processing Record 9 of Set 3 | grand-santi
# Processing Record 10 of Set 3 | chapadinha
# Processing Record 11 of Set 3 | upata
# Processing Record 12 of Set 3 | saint-pierre
# Processing Record 13 of Set 3 | provideniya
# Processing Record 14 of Set 3 | edinburg
# Processing Record 15 of Set 3 | hermanus
# City not found. Skipping...
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | saint-augustin
# Processing Record 18 of Set 3 | souillac
# Processing Record 19 of Set 3 | mackay
# Processing Record 20 of Set 3 | talnakh
# Processing Record 21 of Set 3 | mataura
# Processing Record 22 of Set 3 | pinawa
# Processing Record 23 of Set 3 | atar
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | luau
# Processing Record 26 of Set 3 | nago
# Processing Record 27 of Set 3 | brawley
# Processing Record 28 of Set 3 | karratha
# Processing Record 29 of Set 3 | plover
# Processing Record 30 of Set 3 | benguela
# City not found. Skipping...
# Processing Record 31 of Set 3 | narsaq
# Processing Record 32 of Set 3 | sydney mines
# Processing Record 33 of Set 3 | port macquarie
# City not found. Skipping...
# Processing Record 34 of Set 3 | raga
# Processing Record 35 of Set 3 | chernyshevskiy
# Processing Record 36 of Set 3 | dudinka
# Processing Record 37 of Set 3 | vaini
# Processing Record 38 of Set 3 | malatya
# Processing Record 39 of Set 3 | itarema
# Processing Record 40 of Set 3 | aseri
# Processing Record 41 of Set 3 | gillette
# Processing Record 42 of Set 3 | sterling
# Processing Record 43 of Set 3 | fairbanks
# Processing Record 44 of Set 3 | kautokeino
# Processing Record 45 of Set 3 | lata
# Processing Record 46 of Set 3 | pouembout
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | naze
# Processing Record 49 of Set 3 | aykhal
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | ancud
# Processing Record 3 of Set 4 | ahipara
# Processing Record 4 of Set 4 | kralendijk
# Processing Record 5 of Set 4 | high prairie
# Processing Record 6 of Set 4 | costa rica
# Processing Record 7 of Set 4 | olinda
# Processing Record 8 of Set 4 | kushiro
# Processing Record 9 of Set 4 | montepuez
# Processing Record 10 of Set 4 | iralaya
# Processing Record 11 of Set 4 | akyab
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | tiksi
# Processing Record 14 of Set 4 | olongapo
# Processing Record 15 of Set 4 | nabire
# City not found. Skipping...
# Processing Record 16 of Set 4 | necochea
# Processing Record 17 of Set 4 | vredendal
# City not found. Skipping...
# Processing Record 18 of Set 4 | riyadh
# Processing Record 19 of Set 4 | llandrindod wells
# Processing Record 20 of Set 4 | vanavara
# Processing Record 21 of Set 4 | uruzgan
# Processing Record 22 of Set 4 | bell ville
# City not found. Skipping...
# Processing Record 23 of Set 4 | toronto
# Processing Record 24 of Set 4 | sibiti
# Processing Record 25 of Set 4 | jacksonville
# Processing Record 26 of Set 4 | fortuna
# Processing Record 27 of Set 4 | chilca
# Processing Record 28 of Set 4 | qaqortoq
# Processing Record 29 of Set 4 | egvekinot
# Processing Record 30 of Set 4 | kodiak
# Processing Record 31 of Set 4 | nizhniy tsasuchey
# Processing Record 32 of Set 4 | isiro
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | sigiriya
# Processing Record 35 of Set 4 | sakakah
# Processing Record 36 of Set 4 | inhambane
# Processing Record 37 of Set 4 | ambilobe
# Processing Record 38 of Set 4 | wahiawa
# Processing Record 39 of Set 4 | jawa
# Processing Record 40 of Set 4 | tokmak
# City not found. Skipping...
# Processing Record 41 of Set 4 | mashhad
# City not found. Skipping...
# Processing Record 42 of Set 4 | anadyr
# City not found. Skipping...
# Processing Record 43 of Set 4 | san policarpo
# Processing Record 44 of Set 4 | zhigansk
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | copiapo
# City not found. Skipping...
# Processing Record 47 of Set 4 | saskylakh
# Processing Record 48 of Set 4 | inongo
# Processing Record 49 of Set 4 | upington
# Processing Record 1 of Set 5 | makakilo city
# Processing Record 2 of Set 5 | urusha
# City not found. Skipping...
# Processing Record 3 of Set 5 | chingirlau
# Processing Record 4 of Set 5 | hun
# Processing Record 5 of Set 5 | shirokiy
# Processing Record 6 of Set 5 | nacala
# Processing Record 7 of Set 5 | marfino
# Processing Record 8 of Set 5 | vardo
# Processing Record 9 of Set 5 | ilulissat
# Processing Record 10 of Set 5 | meulaboh
# Processing Record 11 of Set 5 | tomohon
# Processing Record 12 of Set 5 | sioux lookout
# Processing Record 13 of Set 5 | prince rupert
# Processing Record 14 of Set 5 | caravelas
# Processing Record 15 of Set 5 | collie
# Processing Record 16 of Set 5 | verkhnyaya balkariya
# Processing Record 17 of Set 5 | rockport
# City not found. Skipping...
# Processing Record 18 of Set 5 | sibolga
# Processing Record 19 of Set 5 | sao filipe
# Processing Record 20 of Set 5 | metro
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | warragul
# Processing Record 23 of Set 5 | portland
# Processing Record 24 of Set 5 | cayenne
# Processing Record 25 of Set 5 | yaan
# Processing Record 26 of Set 5 | senneterre
# Processing Record 27 of Set 5 | faanui
# Processing Record 28 of Set 5 | yakeshi
# Processing Record 29 of Set 5 | laguna
# Processing Record 30 of Set 5 | acopiara
# Processing Record 31 of Set 5 | cartagena
# Processing Record 32 of Set 5 | coahuayana
# City not found. Skipping...
# Processing Record 33 of Set 5 | lubango
# City not found. Skipping...
# Processing Record 34 of Set 5 | torbay
# Processing Record 35 of Set 5 | mount isa
# Processing Record 36 of Set 5 | mayo
# Processing Record 37 of Set 5 | nanortalik
# City not found. Skipping...
# Processing Record 38 of Set 5 | chardara
# Processing Record 39 of Set 5 | markova
# Processing Record 40 of Set 5 | pangnirtung
# Processing Record 41 of Set 5 | lasa
# Processing Record 42 of Set 5 | oktyabrskiy
# Processing Record 43 of Set 5 | norman wells
# Processing Record 44 of Set 5 | lebu
# Processing Record 45 of Set 5 | adrar
# Processing Record 46 of Set 5 | aasiaat
# Processing Record 47 of Set 5 | dawei
# Processing Record 48 of Set 5 | acapulco
# Processing Record 49 of Set 5 | abeche
# Processing Record 1 of Set 6 | grindavik
# Processing Record 2 of Set 6 | aden
# City not found. Skipping...
# Processing Record 3 of Set 6 | along
# Processing Record 4 of Set 6 | port pirie
# Processing Record 5 of Set 6 | kardla
# Processing Record 6 of Set 6 | maxixe
# City not found. Skipping...
# Processing Record 7 of Set 6 | victoria
# Processing Record 8 of Set 6 | nargana
# Processing Record 9 of Set 6 | gambela
# Processing Record 10 of Set 6 | saldanha
# Processing Record 11 of Set 6 | manavalakurichi
# Processing Record 12 of Set 6 | dali
# Processing Record 13 of Set 6 | carutapera
# City not found. Skipping...
# Processing Record 14 of Set 6 | baiyin
# Processing Record 15 of Set 6 | twin falls
# Processing Record 16 of Set 6 | jinchang
# Processing Record 17 of Set 6 | gouyave
# Processing Record 18 of Set 6 | otavi
# Processing Record 19 of Set 6 | camacha
# Processing Record 20 of Set 6 | san cristobal
# Processing Record 21 of Set 6 | agadir
# Processing Record 22 of Set 6 | upernavik
# Processing Record 23 of Set 6 | inverness
# Processing Record 24 of Set 6 | saint-francois
# Processing Record 25 of Set 6 | salalah
# Processing Record 26 of Set 6 | soe
# Processing Record 27 of Set 6 | acajutla
# Processing Record 28 of Set 6 | clarence town
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 6 | tongzi
# Processing Record 30 of Set 6 | brownwood
# Processing Record 31 of Set 6 | avera
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | sitniki
# Processing Record 34 of Set 6 | lompoc
# Processing Record 35 of Set 6 | luba
# Processing Record 36 of Set 6 | alice springs
# Processing Record 37 of Set 6 | kabinda
# Processing Record 38 of Set 6 | manaquiri
# Processing Record 39 of Set 6 | kampot
# Processing Record 40 of Set 6 | mirzapur
# Processing Record 41 of Set 6 | nome
# City not found. Skipping...
# Processing Record 42 of Set 6 | cooma
# Processing Record 43 of Set 6 | baiao
# Processing Record 44 of Set 6 | pevek
# Processing Record 45 of Set 6 | mana
# Processing Record 46 of Set 6 | bonavista
# Processing Record 47 of Set 6 | saint-georges
# Processing Record 48 of Set 6 | pochutla
# Processing Record 49 of Set 6 | hami
# Processing Record 1 of Set 7 | abu samrah
# City not found. Skipping...
# Processing Record 2 of Set 7 | palermo
# Processing Record 3 of Set 7 | hailey
# Processing Record 4 of Set 7 | sisimiut
# Processing Record 5 of Set 7 | manta
# Processing Record 6 of Set 7 | luderitz
# Processing Record 7 of Set 7 | iquique
# Processing Record 8 of Set 7 | dhidhdhoo
# City not found. Skipping...
# Processing Record 9 of Set 7 | touros
# Processing Record 10 of Set 7 | soke
# Processing Record 11 of Set 7 | aklavik
# Processing Record 12 of Set 7 | college
# Processing Record 13 of Set 7 | saravan
# Processing Record 14 of Set 7 | kawalu
# Processing Record 15 of Set 7 | taoudenni
# City not found. Skipping...
# Processing Record 16 of Set 7 | ibateguara
# Processing Record 17 of Set 7 | pampa
# Processing Record 18 of Set 7 | pandan
# Processing Record 19 of Set 7 | rocky mountain house
# Processing Record 20 of Set 7 | ende
# Processing Record 21 of Set 7 | lakes entrance
# Processing Record 22 of Set 7 | caraballeda
# Processing Record 23 of Set 7 | srednekolymsk
# Processing Record 24 of Set 7 | sitka
# Processing Record 25 of Set 7 | sistranda
# Processing Record 26 of Set 7 | sao jose da coroa grande
# Processing Record 27 of Set 7 | dingle
# Processing Record 28 of Set 7 | yang talat
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 7 | ubinskoye
# Processing Record 30 of Set 7 | waki
# Processing Record 31 of Set 7 | san juan
# Processing Record 32 of Set 7 | bosaso
# Processing Record 33 of Set 7 | paso de los toros
# Processing Record 34 of Set 7 | erenhot
# Processing Record 35 of Set 7 | marquette
# Processing Record 36 of Set 7 | filingue
# City not found. Skipping...
# Processing Record 37 of Set 7 | port hardy
# Processing Record 38 of Set 7 | sydney
# Processing Record 39 of Set 7 | morro bay
# City not found. Skipping...
# Processing Record 40 of Set 7 | olafsvik
# Processing Record 41 of Set 7 | bilibino
# Processing Record 42 of Set 7 | cruzeiro
# Processing Record 43 of Set 7 | kavieng
# Processing Record 44 of Set 7 | mattru
# Processing Record 45 of Set 7 | svetlogorsk
# Processing Record 46 of Set 7 | mahajanga
# Processing Record 47 of Set 7 | santo antonio do sudoeste
# Processing Record 48 of Set 7 | atoyac
# Processing Record 49 of Set 7 | brezice
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 8 | bubaque
# Processing Record 2 of Set 8 | never
# Processing Record 3 of Set 8 | kavaratti
# City not found. Skipping...
# Processing Record 4 of Set 8 | cidreira
# Processing Record 5 of Set 8 | port victoria
# Processing Record 6 of Set 8 | bertoua
# Processing Record 7 of Set 8 | dukat
# Processing Record 8 of Set 8 | kieta
# Processing Record 9 of Set 8 | santa isabel do rio negro
# Processing Record 10 of Set 8 | skelleftea
# Processing Record 11 of Set 8 | nara
# City not found. Skipping...
# Processing Record 12 of Set 8 | zhezkazgan
# Processing Record 13 of Set 8 | rocha
# Processing Record 14 of Set 8 | georgetown
# Processing Record 15 of Set 8 | herat
# Processing Record 16 of Set 8 | pitsunda
# Processing Record 17 of Set 8 | alofi
# Processing Record 18 of Set 8 | marietta
# Processing Record 19 of Set 8 | honiara
# Processing Record 20 of Set 8 | gizo
# Processing Record 21 of Set 8 | marrakesh
# Processing Record 22 of Set 8 | tocopilla
# Processing Record 23 of Set 8 | atikokan
# Processing Record 24 of Set 8 | santa ana
# Processing Record 25 of Set 8 | nianzishan
# Processing Record 26 of Set 8 | plerin
# Processing Record 27 of Set 8 | papara
# Processing Record 28 of Set 8 | venado tuerto
# Processing Record 29 of Set 8 | sao joao do piaui
# Processing Record 30 of Set 8 | abalak
# Processing Record 31 of Set 8 | altamira
# Processing Record 32 of Set 8 | lavrentiya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 8 | bandarbeyla
# Processing Record 34 of Set 8 | cockburn town
# Processing Record 35 of Set 8 | bagotville
# Processing Record 36 of Set 8 | vypolzovo
# Processing Record 37 of Set 8 | salina
# Processing Record 38 of Set 8 | gorom-gorom
# Processing Record 39 of Set 8 | bally
# Processing Record 40 of Set 8 | gat
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | zemio
# Processing Record 43 of Set 8 | hutchinson
# Processing Record 44 of Set 8 | divo
# Processing Record 45 of Set 8 | oyama
# Processing Record 46 of Set 8 | nemuro
# Processing Record 47 of Set 8 | haines junction
# City not found. Skipping...
# Processing Record 48 of Set 8 | tambau
# Processing Record 49 of Set 8 | jibuti
# Processing Record 1 of Set 9 | tortoli
# Processing Record 2 of Set 9 | jinan
# City not found. Skipping...
# Processing Record 3 of Set 9 | virginia beach
# Processing Record 4 of Set 9 | camacupa
# Processing Record 5 of Set 9 | hunsur
# Processing Record 6 of Set 9 | boa vista
# Processing Record 7 of Set 9 | san francisco
# Processing Record 8 of Set 9 | grand gaube
# Processing Record 9 of Set 9 | pontianak
# Processing Record 10 of Set 9 | louis trichardt
# Processing Record 11 of Set 9 | yamoussoukro
# Processing Record 12 of Set 9 | bayangol
# Processing Record 13 of Set 9 | westford
# Processing Record 14 of Set 9 | serrana
# Processing Record 15 of Set 9 | loa janan
# Processing Record 16 of Set 9 | smirice
# Processing Record 17 of Set 9 | bull savanna
# Processing Record 18 of Set 9 | drezdenko
# Processing Record 19 of Set 9 | arman
# Processing Record 20 of Set 9 | ternate
# Processing Record 21 of Set 9 | palmer
# Processing Record 22 of Set 9 | okhotsk
# Processing Record 23 of Set 9 | lima
# Processing Record 24 of Set 9 | krasnyy yar
# City not found. Skipping...
# Processing Record 25 of Set 9 | shache
# Processing Record 26 of Set 9 | vila
# Processing Record 27 of Set 9 | lumeje
# Processing Record 28 of Set 9 | vega de alatorre
# Processing Record 29 of Set 9 | husavik
# Processing Record 30 of Set 9 | san quintin
# Processing Record 31 of Set 9 | carmen
# Processing Record 32 of Set 9 | cabra
# Processing Record 33 of Set 9 | vila franca do campo
# Processing Record 34 of Set 9 | tshela
# Processing Record 35 of Set 9 | ionia
# Processing Record 36 of Set 9 | warrnambool
# Processing Record 37 of Set 9 | nitra
# Processing Record 38 of Set 9 | krutikha
# Processing Record 39 of Set 9 | namibe
# City not found. Skipping...
# Processing Record 40 of Set 9 | kysyl-syr
# Processing Record 41 of Set 9 | orange cove
# City not found. Skipping...
# Processing Record 42 of Set 9 | raigarh
# Processing Record 43 of Set 9 | comodoro rivadavia
# Processing Record 44 of Set 9 | nouadhibou
# Processing Record 45 of Set 9 | darnah
# Processing Record 46 of Set 9 | yining
# Processing Record 47 of Set 9 | faya
# Processing Record 48 of Set 9 | kirakira
# Processing Record 49 of Set 9 | krasnoturansk
# City not found. Skipping...
# Processing Record 1 of Set 10 | isangel
# Processing Record 2 of Set 10 | beloslav
# Processing Record 3 of Set 10 | ayan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 10 | wilmington
# Processing Record 5 of Set 10 | alvaraes
# Processing Record 6 of Set 10 | margate
# City not found. Skipping...
# Processing Record 7 of Set 10 | cuajinicuilapa
# Processing Record 8 of Set 10 | mackenzie
# Processing Record 9 of Set 10 | elko
# Processing Record 10 of Set 10 | half moon bay
# City not found. Skipping...
# Processing Record 11 of Set 10 | verkhoyansk
# Processing Record 12 of Set 10 | kankon
# Processing Record 13 of Set 10 | tateyama
# Processing Record 14 of Set 10 | gawler
# Processing Record 15 of Set 10 | iskateley
# Processing Record 16 of Set 10 | sorokino
# Processing Record 17 of Set 10 | honningsvag
# Processing Record 18 of Set 10 | zhanakorgan
# Processing Record 19 of Set 10 | westport
# Processing Record 20 of Set 10 | alvand
# Processing Record 21 of Set 10 | ust-nera
# Processing Record 22 of Set 10 | angoram
# Processing Record 23 of Set 10 | asau
# Processing Record 24 of Set 10 | mecca
# Processing Record 25 of Set 10 | meadow lake
# Processing Record 26 of Set 10 | ketchikan
# Processing Record 27 of Set 10 | kalmunai
# City not found. Skipping...
# Processing Record 28 of Set 10 | antofagasta
# Processing Record 29 of Set 10 | acarau
# Processing Record 30 of Set 10 | clyde river
# Processing Record 31 of Set 10 | jiazi
# Processing Record 32 of Set 10 | praya
# Processing Record 33 of Set 10 | wittmund
# Processing Record 34 of Set 10 | san marco in lamis
# Processing Record 35 of Set 10 | flinders
# Processing Record 36 of Set 10 | byron bay
# Processing Record 37 of Set 10 | angouleme
# Processing Record 38 of Set 10 | mangit
# Processing Record 39 of Set 10 | coquimbo
# Processing Record 40 of Set 10 | xining
# Processing Record 41 of Set 10 | plouzane
# Processing Record 42 of Set 10 | camana
# Processing Record 43 of Set 10 | miraflores
# Processing Record 44 of Set 10 | mokobeng
# City not found. Skipping...
# Processing Record 45 of Set 10 | sarankhola
# Processing Record 46 of Set 10 | uttarkashi
# Processing Record 47 of Set 10 | daru
# Processing Record 48 of Set 10 | neiafu
# Processing Record 49 of Set 10 | quelimane
# Processing Record 1 of Set 11 | pakpattan
# Processing Record 2 of Set 11 | ayr
# Processing Record 3 of Set 11 | ushibuka
# Processing Record 4 of Set 11 | eurajoki
# Processing Record 5 of Set 11 | koslan
# Processing Record 6 of Set 11 | wanning
# Processing Record 7 of Set 11 | geilo
# Processing Record 8 of Set 11 | mazamet
# Processing Record 9 of Set 11 | vrangel
# Processing Record 10 of Set 11 | sangar
# City not found. Skipping...
# Processing Record 11 of Set 11 | abilene
# Processing Record 12 of Set 11 | burnie
# City not found. Skipping...
# Processing Record 13 of Set 11 | touba
# Processing Record 14 of Set 11 | harper
# Processing Record 15 of Set 11 | broome
# Processing Record 16 of Set 11 | belmonte
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 11 | black diamond
# Processing Record 18 of Set 11 | jiquilisco
# City not found. Skipping...
# Processing Record 19 of Set 11 | mazatlan
# Processing Record 20 of Set 11 | manicore
# Processing Record 21 of Set 11 | grand centre
# Processing Record 22 of Set 11 | uyuni
# Processing Record 23 of Set 11 | shelburne
# Processing Record 24 of Set 11 | partizanskoye
# Processing Record 25 of Set 11 | lazaro cardenas
# Processing Record 26 of Set 11 | pangody
# City not found. Skipping...
# Processing Record 27 of Set 11 | nelson bay
# Processing Record 28 of Set 11 | shar
# Processing Record 29 of Set 11 | tura
# Processing Record 30 of Set 11 | hobyo
# Processing Record 31 of Set 11 | kroya
# Processing Record 32 of Set 11 | tabou
# City not found. Skipping...
# Processing Record 33 of Set 11 | hambantota
# Processing Record 34 of Set 11 | nsanje
# City not found. Skipping...
# Processing Record 35 of Set 11 | tuatapere
# Processing Record 36 of Set 11 | maracas
# Processing Record 37 of Set 11 | muroto
# Processing Record 38 of Set 11 | smithers
# Processing Record 39 of Set 11 | liku
# City not found. Skipping...
# Processing Record 40 of Set 11 | tautira
# Processing Record 41 of Set 11 | marsh harbour
# Processing Record 42 of Set 11 | bengkulu
# Processing Record 43 of Set 11 | macenta
# Processing Record 44 of Set 11 | solnechnyy
# Processing Record 45 of Set 11 | salamiyah
# Processing Record 46 of Set 11 | menongue
# Processing Record 47 of Set 11 | arlit
# Processing Record 48 of Set 11 | yenagoa
# City not found. Skipping...
# Processing Record 49 of Set 11 | paita
# Processing Record 1 of Set 12 | taormina
# Processing Record 2 of Set 12 | dawlatabad
# Processing Record 3 of Set 12 | mercedes
# Processing Record 4 of Set 12 | cabedelo
# Processing Record 5 of Set 12 | sotnikovo
# Processing Record 6 of Set 12 | bang saphan
# Processing Record 7 of Set 12 | pandan niog
# Processing Record 8 of Set 12 | formoso do araguaia
# Processing Record 9 of Set 12 | kloulklubed
# Processing Record 10 of Set 12 | loandjili
# Processing Record 11 of Set 12 | tessalit
# Processing Record 12 of Set 12 | mandera
# Processing Record 13 of Set 12 | bucerias
# City not found. Skipping...
# Processing Record 14 of Set 12 | lorengau
# Processing Record 15 of Set 12 | waipawa
# Processing Record 16 of Set 12 | hargeysa
# Processing Record 17 of Set 12 | kununurra
# Processing Record 18 of Set 12 | flin flon
# Processing Record 19 of Set 12 | katsuura
# Processing Record 20 of Set 12 | san matias
# Processing Record 21 of Set 12 | san miguelito
# Processing Record 22 of Set 12 | idritsa
# City not found. Skipping...
# Processing Record 23 of Set 12 | manati
# Processing Record 24 of Set 12 | matara
# Processing Record 25 of Set 12 | sorong
# City not found. Skipping...
# Processing Record 26 of Set 12 | kudahuvadhoo
# Processing Record 27 of Set 12 | teguldet
# Processing Record 28 of Set 12 | colares
# Processing Record 29 of Set 12 | albacete
# Processing Record 30 of Set 12 | ostrovnoy
# Processing Record 31 of Set 12 | asyut
# Processing Record 32 of Set 12 | mega
# ----------
# Data Retrieval Complete
# --------------------

# %%
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds}



weather_dataframe = pd.DataFrame(weather_dict)


weather_dataframe.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0  port elizabeth          99      CD  1604555730        54  -7.03  29.76
# 1        marsabit          97      KE  1604555731        96   2.33  37.99
# 2       thinadhoo          21      MV  1604555731        71   0.53  72.93
# 3        tasiilaq          73      GL  1604555731        79  65.61 -37.64
# 4    san patricio          79      ML  1604555687        37  13.30  -4.90
#
#    Max Temp  Wind Speed
# 0     81.50        3.58
# 1     64.94       15.97
# 2     83.66        5.46
# 3     15.04       12.84
# 4     74.84        1.41

# %%
weather_dataframe.to_csv(output_data)
weather_dataframe.count()
# Out:
# City          571
# Cloudiness    571
# Country       571
# Date          571
# Humidity      571
# Lat           571
# Lng           571
# Max Temp      571
# Wind Speed    571
# dtype: int64

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures1.png")
plt.show()

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures2.png")
plt.show()

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures3.png")
plt.show()

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("Figures4.png")
plt.show()

# %%
northern_hemisphere = weather_dataframe.loc[weather_dataframe["Lat"] >= 0]
southern_hemisphere = weather_dataframe.loc[weather_dataframe["Lat"] < 0]

# %%
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq


def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
equation = linear_agression(northern_hemisphere["Lat"],northern_hemisphere["Max Temp"])
annotate(equation, 0, 0)
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.savefig("Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.88

# %%
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])
annotate(equation, -30, 50)
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig("Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.66

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])
annotate(equation, 40, 15)
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.29

# %%
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])
annotate(equation, -40, 50)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.03

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])
annotate(equation, 30, 40)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.2

# %%
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])
annotate(equation, -30, 40)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.15

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])
annotate(equation, 40, 20)
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.35

# %%
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])
annotate(equation, -30, 15)
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.33
